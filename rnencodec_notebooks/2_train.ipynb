# %%
# Make repo root importable for this session (zero packaging)
import sys, pathlib
import torch
repo_root = pathlib.Path.cwd().parent if (pathlib.Path.cwd().name == "rnencodec_notebooks") else pathlib.Path.cwd()
sys.path.insert(0, str(repo_root))
# %load_ext autoreload
# %autoreload 2

from datetime import datetime
timestamp = datetime.now().strftime("%y.%m.%d.%H.%M")

dataset_path      = "../trumpet"      # Path to dataset directory
output_model_path = "output_"+timestamp # Path to save the trained model and configs

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Using device: cuda

# %%
from training.loop import train_model

results = train_model(
    dataset_path      = dataset_path,
    model_output_path = output_model_path,
    num_epochs        = 75,      # Number of epochs. 75 works well for most training sessions.
    batch_size        = 100,    # Number of sequences per batch.
    sequence_length   = 125,    # Number of tokens per training sequence.
    batches_per_epoch = 100,    # Number of batches per epoch.
    learning_rate     = 0.005,  # Adam optimizer learning rate.
    hidden_size       = 128,    # GRU hidden state size.
    num_layers        = 3,      # Number of GRU layers in the model.
    save_interval     = 25,     # Save model every N epochs (last checkpoint is always saved).
    add_noise         = True,   # Whether to add noise to embeddings during training.
    noise_weight      = 0.05,   # Weight of noise added to embeddings during training for stability.
    cascade_mode      = "hard", # Codebook learning mode: "hard" or "soft". If "hard", probabilities are used to sample the codebook token. If "soft", probabilities are used as weights for the loss of each codebook.
    temperature       = 0.8,    # Controls randomness when sampling (only for cascade_mode="hard".)
    top_n             = 8,      # Sample from top_n tokens only (only for cascade_mode="hard".)
    tau_soft          = 0.6,    # Soft cascade temperature (only for cascade_mode="soft".)
    train_splits      = None,      # Training split(s) - None for auto-detect, or "train" or ["train", "extra"].
    val_splits        = None, # Validation split(s) - None for auto-detect, or "validation" or ["val1", "val2"].
    TF_schedule       = [4, 4], # Teacher forcing cicle [epochs_on, epochs_off]. Always starts with "on".
    simulate_parallel = False,  # If True, all codebook are learned in parallel (no cascade.)
    use_tensorboard   = True,   # If True, log to TensorBoard.
    use_tqdm          = True,   # If True, show progress bars per epoch.
    val_interval      = 2,      # Run validation every N epochs.
    quantizer_weights = [3.0, 2.0, 1.5, 1.0, 0.8, 0.6, 0.5, 0.4] # Per-codebook loss weights.
)
# Out:
# 🚀 Training Configurations
#
# 💻 Device: cuda:0
# 📋 Conditioning configuration:
#     Features: pitch
#     Total features: 1
#     FPS: 75
# 📊 Available splits: train
# 📦 Creating data loaders...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Latents embedded in 64 of the GRU input size of 128
# Conditioning parameters embedded in 64 of the GRU input size of 128
# 🧠 Model created:
#     Device: cuda:0
#     Conditioning features: 1
#     Hidden size: 128
#     Layers: 3
#     Codebooks: 8
#     Cascade mode: hard
#     Temperature: 0.8
#     Top-k: 8
# 📋 Copied conditioning_config.json to model directory
# saved to /home/frederic/Documents/UPF/semester2/GenAI/audio/generative_audio_final_project/rnencodec_notebooks/output_26.03.19.18.44/config_v2.pt
# wrote json param file
# 💾 Saved conditioning config to: conditioning_config.pt
# 💾 Output directory: /home/frederic/Documents/UPF/semester2/GenAI/audio/generative_audio_final_project/rnencodec_notebooks/output_26.03.19.18.44
# 💾 Saved configuration to: /home/frederic/Documents/UPF/semester2/GenAI/audio/generative_audio_final_project/rnencodec_notebooks/output_26.03.19.18.44/config_v2.pt
#
# 🏋️ Training Started
#
# Epochs: 1 → 75
# Batches per epoch: 100
# Batch size: 100
# TF schedule: [4, 4]
# Simulate parallel: False
# Validation: Disabled
# Tensorboard: Enabled
#     run in a new terminal: tensorboard --logdir=/home/frederic/Documents/UPF/semester2/GenAI/audio/generative_audio_final_project/rnencodec_notebooks/output_26.03.19.18.44/tensorboard
# ======================================================================
# Epoch   1/75 | TF=ON | Training loss: 36.0488
# Epoch   2/75 | TF=ON | Training loss: 27.1219
# Epoch   3/75 | TF=ON | Training loss: 23.7050
# Epoch   4/75 | TF=ON | Training loss: 21.7328
# Epoch   5/75 | TF=OFF | Training loss: 37.3829
# Epoch   6/75 | TF=OFF | Training loss: 29.7381
# Epoch   7/75 | TF=OFF | Training loss: 26.1575
# Epoch   8/75 | TF=OFF | Training loss: 23.8793
# Epoch   9/75 | TF=ON | Training loss: 17.5686
# Epoch  10/75 | TF=ON | Training loss: 14.7512
# Epoch  11/75 | TF=ON | Training loss: 13.5252
# Epoch  12/75 | TF=ON | Training loss: 12.6339
# Epoch  13/75 | TF=OFF | Training loss: 21.5949
# Epoch  14/75 | TF=OFF | Training loss: 18.8728
# Epoch  15/75 | TF=OFF | Training loss: 17.9686
# Epoch  16/75 | TF=OFF | Training loss: 17.4104
# Epoch  17/75 | TF=ON | Training loss: 12.8485
# Epoch  18/75 | TF=ON | Training loss: 11.2380
# Epoch  19/75 | TF=ON | Training loss: 10.5782
# Epoch  20/75 | TF=ON | Training loss: 10.1491
# Epoch  21/75 | TF=OFF | Training loss: 18.7785
# Epoch  22/75 | TF=OFF | Training loss: 16.5847
# Epoch  23/75 | TF=OFF | Training loss: 16.0581
# Epoch  24/75 | TF=OFF | Training loss: 15.7470
# Epoch  25/75 | TF=ON | Training loss: 11.3147
#    💾 Checkpoint saved at epoch 25
# Epoch  26/75 | TF=ON | Training loss: 9.9522
# Epoch  27/75 | TF=ON | Training loss: 9.4642
# Epoch  28/75 | TF=ON | Training loss: 9.1451
# Epoch  29/75 | TF=OFF | Training loss: 17.5744
# Epoch  30/75 | TF=OFF | Training loss: 15.6461
# Epoch  31/75 | TF=OFF | Training loss: 15.1391
# Epoch  32/75 | TF=OFF | Training loss: 14.8901
# Epoch  33/75 | TF=ON | Training loss: 10.5536
# Epoch  34/75 | TF=ON | Training loss: 9.4180
# Epoch  35/75 | TF=ON | Training loss: 8.8737
# Epoch  36/75 | TF=ON | Training loss: 8.6140
# Epoch  37/75 | TF=OFF | Training loss: 16.9186
# Epoch  38/75 | TF=OFF | Training loss: 15.1101
# Epoch  39/75 | TF=OFF | Training loss: 14.6073
# Epoch  40/75 | TF=OFF | Training loss: 14.3765
# Epoch  41/75 | TF=ON | Training loss: 10.0628
# Epoch  42/75 | TF=ON | Training loss: 8.8927
# Epoch  43/75 | TF=ON | Training loss: 8.5012
# Epoch  44/75 | TF=ON | Training loss: 8.2668
# Epoch  45/75 | TF=OFF | Training loss: 16.4894
# Epoch  46/75 | TF=OFF | Training loss: 14.7335
# Epoch  47/75 | TF=OFF | Training loss: 14.2591
# Epoch  48/75 | TF=OFF | Training loss: 14.0767
# Epoch  49/75 | TF=ON | Training loss: 9.7227
# Epoch  50/75 | TF=ON | Training loss: 8.6044
#    💾 Checkpoint saved at epoch 50
# Epoch  51/75 | TF=ON | Training loss: 8.2280
# Epoch  52/75 | TF=ON | Training loss: 8.0047
# Epoch  53/75 | TF=OFF | Training loss: 16.1328
# Epoch  54/75 | TF=OFF | Training loss: 14.3895
# Epoch  55/75 | TF=OFF | Training loss: 13.9588
# Epoch  56/75 | TF=OFF | Training loss: 13.8098
# Epoch  57/75 | TF=ON | Training loss: 9.4635
# Epoch  58/75 | TF=ON | Training loss: 8.3918
# Epoch  59/75 | TF=ON | Training loss: 8.0302
# Epoch  60/75 | TF=ON | Training loss: 7.8116
# Epoch  61/75 | TF=OFF | Training loss: 15.7677
# Epoch  62/75 | TF=OFF | Training loss: 14.1754
# Epoch  63/75 | TF=OFF | Training loss: 13.7755
# Epoch  64/75 | TF=OFF | Training loss: 13.6039
# Epoch  65/75 | TF=ON | Training loss: 9.2474
# Epoch  66/75 | TF=ON | Training loss: 8.2249
# Epoch  67/75 | TF=ON | Training loss: 7.8847
# Epoch  68/75 | TF=ON | Training loss: 7.6716
# Epoch  69/75 | TF=OFF | Training loss: 15.5718
# Epoch  70/75 | TF=OFF | Training loss: 13.9596
# Epoch  71/75 | TF=OFF | Training loss: 13.6168
# Epoch  72/75 | TF=OFF | Training loss: 13.4469
# Epoch  73/75 | TF=ON | Training loss: 9.0857
# Epoch  74/75 | TF=ON | Training loss: 8.0851
# Epoch  75/75 | TF=ON | Training loss: 7.7283
#    💾 Checkpoint saved at epoch 75
#
# 🏋️ Training Completed
#
# Total time: 01:03:21
# Model saved to: /home/frederic/Documents/UPF/semester2/GenAI/audio/generative_audio_final_project/rnencodec_notebooks/output_26.03.19.18.44
# ======================================================================
